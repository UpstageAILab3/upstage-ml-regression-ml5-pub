# %% [markdown]
# # House_Price_Prediction

# %%
# !pip install darts
# Out:
# Requirement already satisfied: darts in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (0.30.0)
# Requirement already satisfied: holidays>=0.11.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from darts) (0.50)
# Requirement already satisfied: joblib>=0.16.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (3.9.1)
# Requirement already satisfied: nfoursid>=1.0.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.0.1)
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.23.5)
# Requirement already satisfied: pmdarima>=1.8.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (2.0.4)
# Requirement already satisfied: pyod>=0.9.5 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (2.0.1)
# Requirement already satisfied: requests>=2.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from darts) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.11.3)
# Requirement already satisfied: shap>=0.40.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (0.46.0)
# Requirement already satisfied: statsforecast>=1.4 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.7.5)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (0.14.0)
# Requirement already satisfied: tbats>=1.1.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (1.1.3)
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (4.12.2)
# Requirement already satisfied: xarray>=0.17.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (2024.6.0)
# Requirement already satisfied: xgboost>=1.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from darts) (2.0.3)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from darts) (2.1.4)
# Requirement already satisfied: tensorboardX>=2.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from darts) (2.3.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from darts) (2.2.2)
# Requirement already satisfied: python-dateutil in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from holidays>=0.11.1->darts) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from matplotlib>=3.3.0->darts) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from pandas>=1.0.5->darts) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->darts) (2024.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from pmdarima>=1.8.0->darts) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pmdarima>=1.8.0->darts) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from pmdarima>=1.8.0->darts) (65.5.0)
# Requirement already satisfied: numba>=0.51 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pyod>=0.9.5->darts) (0.60.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (2024.3.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (1.4.0.post0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (0.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.22.0->darts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.22.0->darts) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.22.0->darts) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from scikit-learn>=1.0.1->darts) (3.5.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from shap>=0.40.0->darts) (0.0.8)
# Requirement already satisfied: cloudpickle in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from shap>=0.40.0->darts) (3.0.0)
# Requirement already satisfied: coreforecast>=0.0.9 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from statsforecast>=1.4->darts) (0.0.10)
# Requirement already satisfied: fugue>=0.8.1 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from statsforecast>=1.4->darts) (0.9.1)
# Requirement already satisfied: utilsforecast>=0.1.4 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from statsforecast>=1.4->darts) (0.1.12)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from statsmodels>=0.14.0->darts) (0.5.6)
# Requirement already satisfied: protobuf>=3.20 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from tensorboardX>=2.1->darts) (4.25.3)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->darts) (3.14.0)
# Requirement already satisfied: sympy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->darts) (1.12.1)
# Requirement already satisfied: networkx in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->darts) (3.3)
# Requirement already satisfied: jinja2 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from torch>=1.8.0->darts) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->darts) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from tqdm>=4.60.0->darts) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (3.9.5)
# Requirement already satisfied: triad>=0.9.7 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.2.4)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->darts) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->darts) (2021.12.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.43.0)
# Requirement already satisfied: six in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.14.0->darts) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from jinja2->torch>=1.8.0->darts) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.9.4)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (16.0.0)
# Requirement already satisfied: fs in c:\users\user\upstage3-python\12.upstage_project_house_price_prediction\dev\env_12\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)

# %%
import matplotlib.pyplot as plt
#plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['font.family'] ='NanumGothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
import os
                        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from darts import TimeSeries
from darts.dataprocessing import Pipeline
from darts.dataprocessing.transformers import Scaler, InvertibleMapper, StaticCovariatesTransformer
from darts.dataprocessing.transformers.missing_values_filler import MissingValuesFiller
from darts.metrics import rmsle
from darts.models import LinearRegressionModel, LightGBMModel, XGBModel, CatBoostModel
from darts.models.filtering.moving_average_filter import MovingAverageFilter
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from tqdm.notebook import tqdm_notebook

plt.style.use("ggplot")
plt.rcParams["font.size"] = 15
COLORS = list(sns.color_palette())
# Out:
# c:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\dev\env_12\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# c:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\dev\env_12\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# c:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\dev\env_12\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %% [markdown]
# # 1. Data Preprocessing

# %%
# helper function to print messages
def cprint(title, *args):
    print(
        "="*len(title), title, "="*len(title),
        *args,
        sep="\n",
    )

# %% [markdown]
# ### Loading the datasets.

# %%
PATH = r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data"

train = pd.read_csv(os.path.join(PATH, "train.csv")) # (1118822, 52)
test = pd.read_csv(os.path.join(PATH, "test.csv")) # (9272, 51)
train_test = pd.read_csv(os.path.join(PATH, "train_test.csv")) # (1128094, 53)
train_test_seoul_apart = pd.read_csv(os.path.join(PATH, "train_test_seoul_apart.csv")) # 
subway_feature = pd.read_csv(os.path.join(PATH, "subway_feature.csv"))
sample_submission = pd.read_csv(os.path.join(PATH, "sample_submission.csv"))
bus_feature = pd.read_csv(os.path.join(PATH, "bus_feature.csv"))
seoul_apart = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\seoul_apart.csv", encoding='utf-8') # (2792, 47)
# 출처: https://data.seoul.go.kr/dataList/OA-15818/S/1/datasetView.do 서울시 공동주택 아파트 정보
doroaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\doroaddress.csv", encoding='utf-8') # (8325, 7)
bunjiaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\bunjiaddress.csv", encoding='utf-8') # (8954, 1) 
# 출처: https://www.juso.go.kr/CommonPageLink.do?link=/support/AddressTransform 100만건 이하 주소전환
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14384\4130116453.py:3: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(os.path.join(PATH, "train.csv")) # (1118822, 52)
# C:\Users\user\AppData\Local\Temp\ipykernel_14384\4130116453.py:5: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_test = pd.read_csv(os.path.join(PATH, "train_test.csv")) # (1128094, 53)
# C:\Users\user\AppData\Local\Temp\ipykernel_14384\4130116453.py:6: DtypeWarning: Columns (17,18,37,72,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_test_seoul_apart = pd.read_csv(os.path.join(PATH, "train_test_seoul_apart.csv")) #

# %% [markdown]
# ## read_csv 만들기 위한 데이터전처리 과정 --> 완료

# %% [markdown]
# ### bunjiaddress

# %%
import pandas as pd

# Assuming 'train_test' is your DataFrame
# Extract unique values from '번지주소' column and convert them to a DataFrame
unique_addresses = pd.DataFrame(train_test['번지주소'].unique(), columns=['Unique Addresses'])

# Save to a CSV file with cp949 encoding, no index, and no header
unique_addresses.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\번지주소.txt", encoding='cp949', index=False, header=False)

# %%
doroaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\도로명주소.txt", encoding='cp949') # 
bunjiaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\번지주소.txt", encoding='cp949') # 

doroaddress.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\도로명주소.txt", encoding='utf-8', index=False)
bunjiaddress.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\번지주소.txt", encoding='utf-8', index=False)

# %%
bunjiaddress.rename(columns={0:'번지주소'}, inplace=True)

# %%
bunjiaddress = bunjiaddress.drop(bunjiaddress.columns[0], axis=1)

# %%
bunjiaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\번지주소.txt", encoding='cp949', header=None) #

# %%
bunjiaddress.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\bunjiaddress.csv", index=False)

# %%
bunjiaddress
# Out:
#                       번지주소
# 0      서울특별시 강남구 개포동 658-1
# 1        서울특별시 강남구 개포동 652
# 2       서울특별시 강남구 개포동 12-2
# 3        서울특별시 강남구 개포동 141
# 4        서울특별시 강남구 개포동 187
# ...                    ...
# 8949  서울특별시 동작구 흑석동 253-89
# 8950   서울특별시 마포구 신수동 400-1
# 8951    서울특별시 성동구 송정동 67-5
# 8952    서울특별시 중구 인현동2가 240
# 8953      서울특별시 중구 입정동 277
#
# [8954 rows x 1 columns]

# %%
bunjiaddress[bunjiaddress['번지주소'].isna()]
# Out:
#      번지주소
# 3578  NaN

# %%
bunjiaddress.drop()

# %% [markdown]
# ### doroaddress

# %%
column_names = ['결과코드', '우편번호', '지번주소', '도로명주소', '건물관리번호']
doroaddress = pd.read_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\도로명주소.txt", delimiter=';', names=column_names, on_bad_lines='warn')

# %%
doroaddress = doroaddress.drop(doroaddress.index[0])

# %%
doroaddress = doroaddress.drop(doroaddress.columns[0], axis=1)

# %%
doroaddress.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\doroaddress.csv", index=False)

# %%
doroaddress['동'] = doroaddress['도로명주소'].str.extract(r'\((.*?)\)')

# %%
doroaddress['도로명주소'] = doroaddress['도로명주소'].str.replace(r'\s*\(.*?\)', '', regex=True)

# %%
print(doroaddress['우편번호'].dtype)
# Out:
# float64

# %%
doroaddress
# Out:
#       결과코드    우편번호                 지번주소                 도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                   NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185     서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                   ...
# 8325  전환성공  6321.0    서울특별시 강남구 개포동 141     서울특별시 강남구 개포로 310
# 8326  전환성공  6329.0    서울특별시 강남구 개포동 187    서울특별시 강남구 삼성로4길 17
# 8327  전환성공  6284.0    서울특별시 강남구 대치동 316     서울특별시 강남구 삼성로 212
# 8328  전환성공  6798.0   서울특별시 서초구 서초동 1326     서울특별시 서초구 서운로 122
# 8329  전환실패  8232.0     서울특별시 구로구 고척동 97         서울 구로구 경서로 17
#
#                          건물관리번호    동                    동도로명주소
# 0     1168010300106580001019759  개포동       서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285  개포동     서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001  개포동  서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN  NaN                       NaN
# 4     1168010300101850000019804  개포동     서울특별시 강남구 개포동 개포로 516
# ...                         ...  ...                       ...
# 8325  1168010300106600001019979  개포동     서울특별시 강남구 개포동 개포로 310
# 8326  1168010300101870000019798  개포동    서울특별시 강남구 개포동 삼성로4길 17
# 8327  1168010600103160000014554  대치동     서울특별시 강남구 대치동 삼성로 212
# 8328  1165010800113260000022501  서초동     서울특별시 서초구 서초동 서운로 122
# 8329  1153010600100970000014298  고척동         서울 구로구 고척동 경서로 17
#
# [8330 rows x 7 columns]

# %%
doroaddress['우편번호']
# Out:
# 0       06316
# 1       06319
# 2       06334
# 3       00000
# 4       06330
#         ...
# 8318    06987
# 8319    04088
# 8320    04802
# 8321    04548
# 8322    04544
# Name: 우편번호, Length: 8323, dtype: object

# %%
# to_csv로 저장해서 불러오면 다시 float64가 됨
def format_postcode(x):
    try:
        # 숫자로 변환, 오류 시 NaN 반환
        num = pd.to_numeric(x, errors='coerce')
        if np.isnan(num):  # NaN 체크
            return None     # 원하는 기본값으로 설정
        return f"{int(num):05}"
    except Exception as e:
        print(f"Error converting {x}: {e}")
        return None  # 오류가 발생했을 때 반환할 값

# apply 함수로 각 요소에 적용
doroaddress['우편번호'] = doroaddress['우편번호'].apply(format_postcode)

# %%
doroaddress[doroaddress['동'].isna()]
# Out:
#       결과코드  우편번호                  지번주소 도로명주소 건물관리번호    동 동도로명주소
# 3     자료없음   0.0     서울특별시 강남구 개포동 141   NaN    NaN  NaN   None
# 223   자료없음   0.0    서울특별시 강남구 삼성동 19-4   NaN    NaN  NaN   None
# 295   자료없음   0.0    서울특별시 강남구 압구정동 443   NaN    NaN  NaN   None
# 305   자료없음   0.0     서울특별시 강남구 역삼동 712   NaN    NaN  NaN   None
# 407   자료없음   0.0   서울특별시 강남구 일원동 690-1   NaN    NaN  NaN   None
# ...    ...   ...                   ...   ...    ...  ...    ...
# 8302  자료없음   0.0     서울특별시 강남구 역삼동 763   NaN    NaN  NaN   None
# 8308  자료없음   0.0    서울특별시 서초구 반포동 16-1   NaN    NaN  NaN   None
# 8309  자료없음   0.0  서울특별시 서초구 서초동 1686-4   NaN    NaN  NaN   None
# 8310  자료없음   0.0   서울특별시 용산구 한강로2가 196   NaN    NaN  NaN   None
# 8317  자료없음   0.0      서울특별시 구로구 고척동 97   NaN    NaN  NaN   None
#
# [246 rows x 7 columns]

# %%
## 동도로명주소

import pandas as pd

# 새로운 주소 컬럼 생성
def create_full_address(row):
    if pd.isna(row['도로명주소']):  # 주소가 NaN인지 확인
        return None  # NaN 값이면 None 반환
    
    parts = row['도로명주소'].split()  # 주소를 공백으로 분할
    new_parts = []
    insert_position = -1  # '동'을 삽입할 위치

    # '서'로 시작하고 '구'로 끝나는 부분까지 new_parts에 추가
    for i, part in enumerate(parts):
        new_parts.append(part)
        if part.endswith('구'):
            insert_position = i + 1  # '구' 다음 위치에 '동' 삽입
            break

    # '동' 삽입
    if insert_position != -1:  # 적절한 삽입 위치가 있으면
        new_parts.insert(insert_position, row['동'])  # '동'을 삽입
        new_parts.extend(parts[insert_position:])  # 나머지 주소 부분 추가

    return ' '.join(new_parts)  # 분할된 파트를 다시 조합

# apply 함수를 사용하여 각 행에 함수 적용
doroaddress['동도로명주소'] = doroaddress.apply(create_full_address, axis=1)

print(doroaddress)
# Out:
#       결과코드    우편번호                 지번주소                   도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1         서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652       서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2    서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                     NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185       서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                     ...
# 8320  전환성공  4802.0   서울특별시 성동구 송정동 67-5        서울특별시 성동구 송정길 32
# 8321  전환성공  4548.0   서울특별시 중구 인현동2가 240        서울특별시 중구 마른내로 79
# 8322  전환성공  4544.0     서울특별시 중구 입정동 277      서울특별시 중구 을지로15길 31
# 8323  전환성공  6800.0    서울특별시 서초구 내곡동 384  서울특별시 서초구 내곡동 헌릉로8길 45
# 8324  전환성공  6798.0    서울특별시 서초구 신원동 557   서울특별시 서초구 헌릉로8길 10-12
#
#                          건물관리번호      동                      동도로명주소
# 0     1168010300106580001019759    개포동         서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285    개포동       서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001    개포동    서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN    NaN                        None
# 4     1168010300101850000019804    개포동       서울특별시 강남구 개포동 개포로 516
# ...                         ...    ...                         ...
# 8320  1120011800100670005003280    송정동        서울특별시 성동구 송정동 송정길 32
# 8321  1114013400101510001014682  인현동2가      서울특별시 중구 인현동2가 마른내로 79
# 8322  1114015600101400004011835    입정동      서울특별시 중구 입정동 을지로15길 31
# 8323  1165010900101430000000001    내곡동  서울특별시 서초구 내곡동 내곡동 헌릉로8길 45
# 8324  1165011100104120005000002    신원동   서울특별시 서초구 신원동 헌릉로8길 10-12
#
# [8325 rows x 7 columns]

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %% [markdown]
# ### train_test

# %%
# train/test 구분을 위한 칼럼을 하나 만들어 줍니다.
train['is_test'] = 0
test['is_test'] = 1
train_test = pd.concat([train, test])     # 하나의 데이터로 만들어줍니다.

# %%
train_test['번지주소'] = train_test['시군구'] + ' ' + train_test['번지']

# %%
train_test = train_test.drop(train_test.columns[0], axis=1)

# %%
train_test.to_csv(r"C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\train_test.csv", index=False)

# %%
train_test['구'] = train_test['시군구'].map(lambda x : x.split()[1])
train_test['동'] = train_test['시군구'].map(lambda x : x.split()[2])

# %%
# 시군구, 년월 등 분할할 수 있는 변수들은 세부사항 고려를 용이하게 하기 위해 모두 분할해 주겠습니다.
train_test['구'] = train_test['시군구'].map(lambda x : x.split()[1])
train_test['동'] = train_test['시군구'].map(lambda x : x.split()[2])
del train_test['시군구']

train_test['계약년'] = train_test['계약년월'].astype('str').map(lambda x : x[:4])
train_test['계약월'] = train_test['계약년월'].astype('str').map(lambda x : x[4:])
del train_test['계약년월']

# %%
train_test['도로명주소'] =  '서울특별시'+' '+ train_test['구']+ ' '+train_test['동']+ ' ' +train_test['도로명']

# %%
train_test.rename(columns={'도로명주소':'동도로명주소'}, inplace=True)

# %%
train_test = pd.merge(train_test, doroaddress, left_on='동도로명주소', right_on='동도로명주소', how='left')

# %%
train_test
# Out:
#             번지     본번   부번      아파트명  전용면적(㎡)  계약일   층  건축년도        도로명  \
# 0        658-1  658.0  1.0    개포6차우성    79.97    8   3  1987      언주로 3
# 1        658-1  658.0  1.0    개포6차우성    79.97   22   4  1987      언주로 3
# 2        658-1  658.0  1.0    개포6차우성    54.98   28   5  1987      언주로 3
# 3        658-1  658.0  1.0    개포6차우성    79.97    3   4  1987      언주로 3
# 4        658-1  658.0  1.0    개포6차우성    79.97    8   2  1987      언주로 3
# ...        ...    ...  ...       ...      ...  ...  ..   ...        ...
# 1142211    816  816.0  0.0  신내우디안1단지    84.65   19  13  2014  신내역로1길 85
# 1142212    816  816.0  0.0  신내우디안1단지    84.62   25  12  2014  신내역로1길 85
# 1142213    816  816.0  0.0  신내우디안1단지   101.65   27  12  2014  신내역로1길 85
# 1142214    816  816.0  0.0  신내우디안1단지    84.94    2  18  2014  신내역로1길 85
# 1142215    816  816.0  0.0  신내우디안1단지    84.65    4  13  2014  신내역로1길 85
#
#             해제사유발생일    등기신청일자  거래유형  중개사소재지 k-단지분류(아파트,주상복합등등)     k-전화번호  \
# 0               NaN               -       -                아파트  025776611
# 1               NaN               -       -                아파트  025776611
# 2               NaN               -       -                아파트  025776611
# 3               NaN               -       -                아파트  025776611
# 4               NaN               -       -                아파트  025776611
# ...             ...       ...   ...     ...                ...        ...
# 1142211  20230801.0             직거래       -                아파트  024969683
# 1142212         NaN            중개거래  서울 중랑구                아파트  024969683
# 1142213         NaN            중개거래  서울 중랑구                아파트  024969683
# 1142214         NaN            중개거래  서울 중랑구                아파트  024969683
# 1142215         NaN  20230905   직거래       -                아파트  024969683
#
#             k-팩스번호  단지소개기존clob k-세대타입(분양형태) k-관리방식 k-복도유형 k-난방방식  k-전체동수  \
# 0        025776673         NaN           분양   자치관리    계단식   개별난방     8.0
# 1        025776673         NaN           분양   자치관리    계단식   개별난방     8.0
# 2        025776673         NaN           분양   자치관리    계단식   개별난방     8.0
# 3        025776673         NaN           분양   자치관리    계단식   개별난방     8.0
# 4        025776673         NaN           분양   자치관리    계단식   개별난방     8.0
# ...            ...         ...          ...    ...    ...    ...     ...
# 1142211  024969685         4.0           기타   위탁관리    혼합식   개별난방    16.0
# 1142212  024969685         4.0           기타   위탁관리    혼합식   개별난방    16.0
# 1142213  024969685         4.0           기타   위탁관리    혼합식   개별난방    16.0
# 1142214  024969685         4.0           기타   위탁관리    혼합식   개별난방    16.0
# 1142215  024969685         4.0           기타   위탁관리    혼합식   개별난방    16.0
#
#          k-전체세대수 k-건설사(시공사) k-시행사          k-사용검사일-사용승인일     k-연면적  k-주거전용면적  \
# 0          270.0       우성건설    모름  1987-11-21 00:00:00.0   22637.0   20204.0
# 1          270.0       우성건설    모름  1987-11-21 00:00:00.0   22637.0   20204.0
# 2          270.0       우성건설    모름  1987-11-21 00:00:00.0   22637.0   20204.0
# 3          270.0       우성건설    모름  1987-11-21 00:00:00.0   22637.0   20204.0
# 4          270.0       우성건설    모름  1987-11-21 00:00:00.0   22637.0   20204.0
# ...          ...        ...   ...                    ...       ...       ...
# 1142211   1402.0    한신공영(주)  SH공사  2014-06-18 00:00:00.0  190866.0   93849.0
# 1142212   1402.0    한신공영(주)  SH공사  2014-06-18 00:00:00.0  190866.0   93849.0
# 1142213   1402.0    한신공영(주)  SH공사  2014-06-18 00:00:00.0  190866.0   93849.0
# 1142214   1402.0    한신공영(주)  SH공사  2014-06-18 00:00:00.0  190866.0   93849.0
# 1142215   1402.0    한신공영(주)  SH공사  2014-06-18 00:00:00.0  190866.0   93849.0
#
#          k-관리비부과면적  k-전용면적별세대현황(60㎡이하)  k-전용면적별세대현황(60㎡~85㎡이하)  k-85㎡~135㎡이하  \
# 0          22637.0                20.0                   250.0           0.0
# 1          22637.0                20.0                   250.0           0.0
# 2          22637.0                20.0                   250.0           0.0
# 3          22637.0                20.0                   250.0           0.0
# 4          22637.0                20.0                   250.0           0.0
# ...            ...                 ...                     ...           ...
# 1142211    92808.0               808.0                   504.0          90.0
# 1142212    92808.0               808.0                   504.0          90.0
# 1142213    92808.0               808.0                   504.0          90.0
# 1142214    92808.0               808.0                   504.0          90.0
# 1142215    92808.0               808.0                   504.0          90.0
#
#          k-135㎡초과 k-홈페이지                 k-등록일자                 k-수정일자  \
# 0             NaN    NaN  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0
# 1             NaN    NaN  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0
# 2             NaN    NaN  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0
# 3             NaN    NaN  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0
# 4             NaN    NaN  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0
# ...           ...    ...                    ...                    ...
# 1142211       NaN    NaN                    NaN  2023-09-23 09:00:52.0
# 1142212       NaN    NaN                    NaN  2023-09-23 09:00:52.0
# 1142213       NaN    NaN                    NaN  2023-09-23 09:00:52.0
# 1142214       NaN    NaN                    NaN  2023-09-23 09:00:52.0
# 1142215       NaN    NaN                    NaN  2023-09-23 09:00:52.0
#
#            고용보험관리번호 경비비관리형태 세대전기계약방법 청소비관리형태     건축면적    주차대수  \
# 0               NaN      직영     단일계약      직영   4858.0   262.0
# 1               NaN      직영     단일계약      직영   4858.0   262.0
# 2               NaN      직영     단일계약      직영   4858.0   262.0
# 3               NaN      직영     단일계약      직영   4858.0   262.0
# 4               NaN      직영     단일계약      직영   4858.0   262.0
# ...             ...     ...      ...     ...      ...     ...
# 1142211  2048279333      위탁     종합계약      위탁  14171.0  1568.0
# 1142212  2048279333      위탁     종합계약      위탁  14171.0  1568.0
# 1142213  2048279333      위탁     종합계약      위탁  14171.0  1568.0
# 1142214  2048279333      위탁     종합계약      위탁  14171.0  1568.0
# 1142215  2048279333      위탁     종합계약      위탁  14171.0  1568.0
#
#         기타/의무/임대/임의=1/2/3/4                  단지승인일 사용허가여부 관리비 업로드        좌표X  \
# 0                        임의  2022-11-17 13:00:29.0      Y       N  127.05721
# 1                        임의  2022-11-17 13:00:29.0      Y       N  127.05721
# 2                        임의  2022-11-17 13:00:29.0      Y       N  127.05721
# 3                        임의  2022-11-17 13:00:29.0      Y       N  127.05721
# 4                        임의  2022-11-17 13:00:29.0      Y       N  127.05721
# ...                     ...                    ...    ...     ...        ...
# 1142211                  의무  2015-09-09 15:30:27.0      Y       N  127.10672
# 1142212                  의무  2015-09-09 15:30:27.0      Y       N  127.10672
# 1142213                  의무  2015-09-09 15:30:27.0      Y       N  127.10672
# 1142214                  의무  2015-09-09 15:30:27.0      Y       N  127.10672
# 1142215                  의무  2015-09-09 15:30:27.0      Y       N  127.10672
#
#                좌표Y                  단지신청일    target  is_test  \
# 0        37.476763  2022-11-17 10:19:06.0  124000.0        0
# 1        37.476763  2022-11-17 10:19:06.0  123500.0        0
# 2        37.476763  2022-11-17 10:19:06.0   91500.0        0
# 3        37.476763  2022-11-17 10:19:06.0  130000.0        0
# 4        37.476763  2022-11-17 10:19:06.0  117000.0        0
# ...            ...                    ...       ...      ...
# 1142211  37.618870  2014-09-01 13:05:03.0       NaN        1
# 1142212  37.618870  2014-09-01 13:05:03.0       NaN        1
# 1142213  37.618870  2014-09-01 13:05:03.0       NaN        1
# 1142214  37.618870  2014-09-01 13:05:03.0       NaN        1
# 1142215  37.618870  2014-09-01 13:05:03.0       NaN        1
#
#                         번지주소    구  동_x   계약년 계약월                   동도로명주소  \
# 0        서울특별시 강남구 개포동 658-1  강남구  개포동  2017  12      서울특별시 강남구 개포동 언주로 3
# 1        서울특별시 강남구 개포동 658-1  강남구  개포동  2017  12      서울특별시 강남구 개포동 언주로 3
# 2        서울특별시 강남구 개포동 658-1  강남구  개포동  2017  12      서울특별시 강남구 개포동 언주로 3
# 3        서울특별시 강남구 개포동 658-1  강남구  개포동  2018  01      서울특별시 강남구 개포동 언주로 3
# 4        서울특별시 강남구 개포동 658-1  강남구  개포동  2018  01      서울특별시 강남구 개포동 언주로 3
# ...                      ...  ...  ...   ...  ..                      ...
# 1142211    서울특별시 중랑구 신내동 816  중랑구  신내동  2023  07  서울특별시 중랑구 신내동 신내역로1길 85
# 1142212    서울특별시 중랑구 신내동 816  중랑구  신내동  2023  07  서울특별시 중랑구 신내동 신내역로1길 85
# 1142213    서울특별시 중랑구 신내동 816  중랑구  신내동  2023  08  서울특별시 중랑구 신내동 신내역로1길 85
# 1142214    서울특별시 중랑구 신내동 816  중랑구  신내동  2023  09  서울특별시 중랑구 신내동 신내역로1길 85
# 1142215    서울특별시 중랑구 신내동 816  중랑구  신내동  2023  09  서울특별시 중랑구 신내동 신내역로1길 85
#
#          결과코드    우편번호                 지번주소                도로명주소  \
# 0        전환성공  6316.0  서울특별시 강남구 개포동 658-1      서울특별시 강남구 언주로 3
# 1        전환성공  6316.0  서울특별시 강남구 개포동 658-1      서울특별시 강남구 언주로 3
# 2        전환성공  6316.0  서울특별시 강남구 개포동 658-1      서울특별시 강남구 언주로 3
# 3        전환성공  6316.0  서울특별시 강남구 개포동 658-1      서울특별시 강남구 언주로 3
# 4        전환성공  6316.0  서울특별시 강남구 개포동 658-1      서울특별시 강남구 언주로 3
# ...       ...     ...                  ...                  ...
# 1142211  전환성공  2055.0    서울특별시 중랑구 신내동 816  서울특별시 중랑구 신내역로1길 85
# 1142212  전환성공  2055.0    서울특별시 중랑구 신내동 816  서울특별시 중랑구 신내역로1길 85
# 1142213  전환성공  2055.0    서울특별시 중랑구 신내동 816  서울특별시 중랑구 신내역로1길 85
# 1142214  전환성공  2055.0    서울특별시 중랑구 신내동 816  서울특별시 중랑구 신내역로1길 85
# 1142215  전환성공  2055.0    서울특별시 중랑구 신내동 816  서울특별시 중랑구 신내역로1길 85
#
#                             건물관리번호  동_y
# 0        1168010300106580001019759  개포동
# 1        1168010300106580001019759  개포동
# 2        1168010300106580001019759  개포동
# 3        1168010300106580001019759  개포동
# 4        1168010300106580001019759  개포동
# ...                            ...  ...
# 1142211  1126010600101860000000001  신내동
# 1142212  1126010600101860000000001  신내동
# 1142213  1126010600101860000000001  신내동
# 1142214  1126010600101860000000001  신내동
# 1142215  1126010600101860000000001  신내동
#
# [1142216 rows x 63 columns]

# %%
filtered = train_test[train_test['지번주소'].isna()][['번지주소','동도로명주소']]
# '번지주소'와 '동도로명주소' 컬럼 조합에서 중복 제거
unique_combinations = filtered.drop_duplicates(subset=['번지주소', '동도로명주소'])
print(unique_combinations)
# Out:
#                         번지주소                    동도로명주소
# 44         서울특별시 강남구 개포동 141       서울특별시 강남구 개포동 선릉로 7
# 997        서울특별시 강남구 개포동 189      서울특별시 강남구 개포동 삼성로 14
# 1087        서울특별시 강남구 개포동 12  서울특별시 강남구 개포동 개포로109길 21
# 1142        서울특별시 강남구 개포동 12   서울특별시 강남구 개포동 개포로109길 9
# 1243       서울특별시 강남구 개포동 656      서울특별시 강남구 개포동 언주로 21
# ...                      ...                       ...
# 1123539     서울특별시 송파구 송파동 33    서울특별시 송파구 송파동 송파대로48길
# 1127808  서울특별시 용산구 한강로2가 196         서울특별시 용산구 한강로2가
# 1132126     서울특별시 동작구 본동 482    서울특별시 동작구 본동 노량진로23가길
# 1135187     서울특별시 구로구 고척동 97      서울특별시 구로구 고척동 경서로 17
# 1135919  서울특별시 노원구 월계동 803-1  서울특별시 노원구 월계동 덕릉로60길 268
#
# [1378 rows x 2 columns]

# %%
train_test[train_test['지번주소'].isna()]['번지주소'].unique()
# Out:
# array(['서울특별시 강남구 개포동 141', '서울특별시 강남구 개포동 187', '서울특별시 강남구 대치동 316', ...,
#        '서울특별시 서초구 서초동 1326', '서울특별시 용산구 한강로2가 196', '서울특별시 구로구 고척동 97'],
#       dtype=object)

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# 안녕하세요.
# 도로명주소 도움센터입니다.
#
# 확인 결과 해당 2개 지번에는 도로명주소가 부여되어 있지 않습니다.
# 도로명주소는 생활주소지 개념으로 건물에 부여되는 주소로 건물이 없는 토지는 지번 그대로 사용합니다.
#
# 주소정보누리집에서는 모든 지번을 제공하는것은 아니며
# 도로명주소가 부여된 지번과 관련 정보를 주소데이터로 제공합니다.
#
# 만약, 건물이 있는데 도로명주소가 부여가 되어 있지 않은 경우는
# 각 지자체(구로구 ☎ 02-860-2797, 광명시 ☎ 02-2680-2158)로 문의주시기 바랍니다.
#
# 안내해 드린 내용이 도움이 되시기를 바라며,
# 기타 문의사항은 ☎ 1588-0061(7번 도로명주소)로 문의주시기 바랍니다.
#
# 감사합니다.
#
#
# 서울특별시 용산구 한강로2가 196 --> 짓는중

# %%
# '지번주소'가 '서울특별시 구로구 고척동 97'인 행 찾기
condition = doroaddress['지번주소'] == '서울특별시 구로구 고척동 97'

# 조건을 만족하는 행의 '결과코드'를 '전환성공'으로 변경
doroaddress.loc[condition, '결과코드'] = '전환성공'

# 결과 출력
print(doroaddress)
# Out:
#       결과코드    우편번호                 지번주소                 도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                   NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185     서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                   ...
# 8325  전환성공  6321.0    서울특별시 강남구 개포동 141     서울특별시 강남구 개포로 310
# 8326  전환성공  6329.0    서울특별시 강남구 개포동 187    서울특별시 강남구 삼성로4길 17
# 8327  전환성공  6284.0    서울특별시 강남구 대치동 316     서울특별시 강남구 삼성로 212
# 8328  전환성공  6798.0   서울특별시 서초구 서초동 1326     서울특별시 서초구 서운로 122
# 8329  전환성공  8232.0     서울특별시 구로구 고척동 97         서울 구로구 경서로 17
#
#                          건물관리번호    동                    동도로명주소
# 0     1168010300106580001019759  개포동       서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285  개포동     서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001  개포동  서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN  NaN                       NaN
# 4     1168010300101850000019804  개포동     서울특별시 강남구 개포동 개포로 516
# ...                         ...  ...                       ...
# 8325  1168010300106600001019979  개포동     서울특별시 강남구 개포동 개포로 310
# 8326  1168010300101870000019798  개포동    서울특별시 강남구 개포동 삼성로4길 17
# 8327  1168010600103160000014554  대치동     서울특별시 강남구 대치동 삼성로 212
# 8328  1165010800113260000022501  서초동     서울특별시 서초구 서초동 서운로 122
# 8329  1153010600100970000014298  고척동         서울 구로구 고척동 경서로 17
#
# [8330 rows x 7 columns]

# %%
# 새로운 행 데이터
new_rows = [
    ['전환성공', '06321', '서울특별시 강남구 개포동 141', '서울특별시 강남구 개포로 310', '1168010300106600001019979', '개포동', '서울특별시 강남구 개포동 개포로 310'],
    ['전환성공', '06329', '서울특별시 강남구 개포동 187', '서울특별시 강남구 삼성로4길 17', '1168010300101870000019798', '개포동', '서울특별시 강남구 개포동 삼성로4길 17'],
    ['전환성공', '06284', '서울특별시 강남구 대치동 316', '서울특별시 강남구 삼성로 212', '1168010600103160000014554', '대치동', '서울특별시 강남구 대치동 삼성로 212'],
    ['전환성공', '06798', '서울특별시 서초구 서초동 1326', '서울특별시 서초구 서운로 122', '1165010800113260000022501', '서초동', '서울특별시 서초구 서초동 서운로 122'],
    #['전환실패', '00000', '서울특별시 용산구 한강로2가 196', , '1165011100104120005000002', , ''],
    ['전환성공', '08232', '서울특별시 구로구 고척동 97', '서울 구로구 경서로 17', '1153010600100970000014298', '고척동', '서울 구로구 고척동 경서로 17']
]

# 새로운 데이터프레임 생성
new_data = pd.DataFrame(new_rows, columns=['결과코드', '우편번호', '지번주소', '도로명주소', '건물관리번호', '동', '동도로명주소'])

# 기존 데이터프레임에 새로운 행 추가
doroaddress = pd.concat([doroaddress, new_data], ignore_index=True)

# 결과 출력
print(doroaddress)
# Out:
#       결과코드    우편번호                 지번주소                 도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1       서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652     서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2  서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                   NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185     서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                   ...
# 8325  전환성공   06321    서울특별시 강남구 개포동 141     서울특별시 강남구 개포로 310
# 8326  전환성공   06329    서울특별시 강남구 개포동 187    서울특별시 강남구 삼성로4길 17
# 8327  전환성공   06284    서울특별시 강남구 대치동 316     서울특별시 강남구 삼성로 212
# 8328  전환성공   06798   서울특별시 서초구 서초동 1326     서울특별시 서초구 서운로 122
# 8329  전환실패   08232     서울특별시 구로구 고척동 97         서울 구로구 경서로 17
#
#                          건물관리번호    동                    동도로명주소
# 0     1168010300106580001019759  개포동       서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285  개포동     서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001  개포동  서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN  NaN                       NaN
# 4     1168010300101850000019804  개포동     서울특별시 강남구 개포동 개포로 516
# ...                         ...  ...                       ...
# 8325  1168010300106600001019979  개포동     서울특별시 강남구 개포동 개포로 310
# 8326  1168010300101870000019798  개포동    서울특별시 강남구 개포동 삼성로4길 17
# 8327  1168010600103160000014554  대치동     서울특별시 강남구 대치동 삼성로 212
# 8328  1165010800113260000022501  서초동     서울특별시 서초구 서초동 서운로 122
# 8329  1153010600100970000014298  고척동         서울 구로구 고척동 경서로 17
#
# [8330 rows x 7 columns]

# %%
doroaddress[doroaddress.지번주소.str.contains('한강로2가 196')==True]
# Out:
#       결과코드  우편번호                 지번주소 도로명주소 건물관리번호    동 동도로명주소
# 8310  자료없음   0.0  서울특별시 용산구 한강로2가 196   NaN    NaN  NaN    NaN

# %%
train_test[train_test['번지주소'].str.contains('한강로2가 196')==True]
# Out:
#                      시군구   번지     본번   부번   아파트명  전용면적(㎡)    계약년월  계약일  층  \
# 1113986  서울특별시 용산구 한강로2가  196  196.0  0.0  신용산빌딩    67.53  200701   17  3
#
#          건축년도 도로명  해제사유발생일 등기신청일자 거래유형 중개사소재지 k-단지분류(아파트,주상복합등등) k-전화번호  \
# 1113986  1984          NaN           -      -                NaN    NaN
#
#         k-팩스번호  단지소개기존clob k-세대타입(분양형태) k-관리방식 k-복도유형 k-난방방식  k-전체동수  k-전체세대수  \
# 1113986    NaN         NaN          NaN    NaN    NaN    NaN     NaN      NaN
#
#         k-건설사(시공사) k-시행사 k-사용검사일-사용승인일  k-연면적  k-주거전용면적  k-관리비부과면적  \
# 1113986        NaN   NaN           NaN    NaN       NaN        NaN
#
#          k-전용면적별세대현황(60㎡이하)  k-전용면적별세대현황(60㎡~85㎡이하)  k-85㎡~135㎡이하  k-135㎡초과  \
# 1113986                 NaN                     NaN           NaN       NaN
#
#         k-홈페이지 k-등록일자 k-수정일자 고용보험관리번호 경비비관리형태 세대전기계약방법 청소비관리형태  건축면적  주차대수  \
# 1113986    NaN    NaN    NaN      NaN     NaN      NaN     NaN   NaN   NaN
#
#         기타/의무/임대/임의=1/2/3/4 단지승인일 사용허가여부 관리비 업로드  좌표X  좌표Y 단지신청일   target  \
# 1113986                 NaN   NaN    NaN     NaN  NaN  NaN   NaN  42750.0
#
#          is_test                 번지주소
# 1113986        0  서울특별시 용산구 한강로2가 196

# %%
train_test[train_test['지번주소'].isna()]['동도로명주소'].unique()
# Out:
# array(['서울특별시 강남구 개포동 개포로 310', '서울특별시 강남구 개포동 선릉로 7',
#        '서울특별시 강남구 개포동 삼성로4길 17', ..., '서울특별시 동작구 본동 노량진로23가길 ',
#        '서울특별시 구로구 고척동 경서로 17', '서울특별시 노원구 월계동 덕릉로60길 268'], dtype=object)

# %%
# 새로운 행 데이터
new_rows = [
    ['전환성공', 06321, '서울특별시 강남구 개포동 개포로 310', '서울특별시 강남구 개포로 310', '1168010300106600001019979', '개포동', '서울특별시 강남구 개포동 개포로 310'],
    ['전환성공', 6798.0, '서울특별시 서초구 신원동 557', '서울특별시 서초구 헌릉로8길 10-12', '1165011100104120005000002', '신원동', '서울특별시 서초구 신원동 헌릉로8길 10-12']
]

# 새로운 데이터프레임 생성
new_data = pd.DataFrame(new_rows, columns=['결과코드', '우편번호', '지번주소', '도로명주소', '건물관리번호', '동', '동도로명주소'])

# 기존 데이터프레임에 새로운 행 추가
doroaddress = pd.concat([doroaddress, new_data], ignore_index=True)

# 결과 출력
print(doroaddress)

# %% [markdown]
# ## 결측치 추가 업데이트

# %%
train_test[train_test['도로명주소_x'].str.contains('헌릉로8길 45')].tail(1)
# Out:
#           번지   본번   부번       아파트명  전용면적(㎡)  계약일   층  건축년도       도로명  해제사유발생일  \
# 1137665  NaN  0.0  0.0  서초포레스타2단지    84.48   22  11  2015  헌릉로8길 45      NaN
#
#         등기신청일자  거래유형  중개사소재지 k-단지분류(아파트,주상복합등등)      k-전화번호      k-팩스번호  \
# 1137665         중개거래  서울 서초구                아파트  0220579560  0220579562
#
#          단지소개기존clob k-세대타입(분양형태) k-관리방식 k-복도유형 k-난방방식  k-전체동수  k-전체세대수  \
# 1137665         NaN           기타   위탁관리    복도식   개별난방    13.0   1077.0
#
#         k-건설사(시공사)   k-시행사          k-사용검사일-사용승인일     k-연면적  k-주거전용면적  \
# 1137665       고려개발  에스에치공사  2015-06-18 00:00:00.0  134431.0   59281.0
#
#          k-관리비부과면적  k-전용면적별세대현황(60㎡이하)  k-전용면적별세대현황(60㎡~85㎡이하)  k-85㎡~135㎡이하  \
# 1137665   134431.0               930.0                   147.0           0.0
#
#          k-135㎡초과 k-홈페이지 k-등록일자                 k-수정일자 고용보험관리번호 경비비관리형태  \
# 1137665       NaN    NaN    NaN  2023-09-23 16:53:27.0      NaN      위탁
#
#         세대전기계약방법 청소비관리형태    건축면적    주차대수 기타/의무/임대/임의=1/2/3/4  \
# 1137665     단일계약      위탁  8252.0  1185.0                  의무
#
#                          단지승인일 사용허가여부 관리비 업로드         좌표X        좌표Y  \
# 1137665  2019-04-24 15:11:04.0      Y       N  127.062596  37.454703
#
#                          단지신청일  target  is_test 번지주소    구  동_x   계약년 계약월  \
# 1137665  2015-07-17 11:07:27.0     NaN        1  NaN  서초구  내곡동  2023  08
#
#                         도로명주소_x 결과코드  우편번호 지번주소 도로명주소_y 건물관리번호  동_y 동도로명주소
# 1137665  서울특별시 서초구 내곡동 헌릉로8길 45  NaN   NaN  NaN     NaN    NaN  NaN    NaN

# %%
filtered_data = train_test[train_test['도로명주소_x'].notna() & train_test['번지주소'].isna()]

# %%
filtered_data['도로명주소_x'].unique()
# Out:
# array(['서울특별시 서초구 내곡동 헌릉로8길 45', '서울특별시 서초구 신원동 헌릉로8길 10-12'],
#       dtype=object)

# %%
'전환성공',	'6800.0',	'서울특별시 서초구 내곡동 384',	'서울특별시 서초구 내곡동 헌릉로8길 45',	'1165010900101430000000001'	,'내곡동',	'서울특별시 서초구 헌릉로8길 45'

# %%
'전환성공',	'6798.0',	'서울특별시 서초구 신원동 557',	'서울특별시 서초구 헌릉로8길 10-12',	'1165011100104120005000002'	,'신원동 ',	'서울특별시 서초구 신원동 헌릉로8길 10-12'

# %%
# 새로운 행 데이터
new_rows = [
    ['전환성공', 6800.0, '서울특별시 서초구 내곡동 384', '서울특별시 서초구 내곡동 헌릉로8길 45', '1165010900101430000000001', '내곡동', '서울특별시 서초구 헌릉로8길 45'],
    ['전환성공', 6798.0, '서울특별시 서초구 신원동 557', '서울특별시 서초구 헌릉로8길 10-12', '1165011100104120005000002', '신원동', '서울특별시 서초구 신원동 헌릉로8길 10-12']
]

# 새로운 데이터프레임 생성
new_data = pd.DataFrame(new_rows, columns=['결과코드', '우편번호', '지번주소', '도로명주소', '건물관리번호', '동', '동도로명주소'])

# 기존 데이터프레임에 새로운 행 추가
doroaddress = pd.concat([doroaddress, new_data], ignore_index=True)

# 결과 출력
print(doroaddress)
# Out:
#       결과코드    우편번호                 지번주소                   도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1         서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652       서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2    서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                     NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185       서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                     ...
# 8320  전환성공  4802.0   서울특별시 성동구 송정동 67-5        서울특별시 성동구 송정길 32
# 8321  전환성공  4548.0   서울특별시 중구 인현동2가 240        서울특별시 중구 마른내로 79
# 8322  전환성공  4544.0     서울특별시 중구 입정동 277      서울특별시 중구 을지로15길 31
# 8323  전환성공  6800.0    서울특별시 서초구 내곡동 384  서울특별시 서초구 내곡동 헌릉로8길 45
# 8324  전환성공  6798.0    서울특별시 서초구 신원동 557   서울특별시 서초구 헌릉로8길 10-12
#
#                          건물관리번호      동                     동도로명주소
# 0     1168010300106580001019759    개포동        서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285    개포동      서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001    개포동   서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN    NaN                        NaN
# 4     1168010300101850000019804    개포동      서울특별시 강남구 개포동 개포로 516
# ...                         ...    ...                        ...
# 8320  1120011800100670005003280    송정동       서울특별시 성동구 송정동 송정길 32
# 8321  1114013400101510001014682  인현동2가     서울특별시 중구 인현동2가 마른내로 79
# 8322  1114015600101400004011835    입정동     서울특별시 중구 입정동 을지로15길 31
# 8323  1165010900101430000000001    내곡동         서울특별시 서초구 헌릉로8길 45
# 8324  1165011100104120005000002    신원동  서울특별시 서초구 신원동 헌릉로8길 10-12
#
# [8325 rows x 7 columns]

# %%
doroaddress
# Out:
#       결과코드    우편번호                 지번주소                   도로명주소  \
# 0     전환성공  6316.0  서울특별시 강남구 개포동 658-1         서울특별시 강남구 언주로 3
# 1     전환성공  6319.0    서울특별시 강남구 개포동 652       서울특별시 강남구 개포로 307
# 2     전환성공  6334.0   서울특별시 강남구 개포동 12-2    서울특별시 강남구 개포로109길 69
# 3     자료없음     0.0    서울특별시 강남구 개포동 141                     NaN
# 4     전환성공  6330.0    서울특별시 강남구 개포동 185       서울특별시 강남구 개포로 516
# ...    ...     ...                  ...                     ...
# 8320  전환성공  4802.0   서울특별시 성동구 송정동 67-5        서울특별시 성동구 송정길 32
# 8321  전환성공  4548.0   서울특별시 중구 인현동2가 240        서울특별시 중구 마른내로 79
# 8322  전환성공  4544.0     서울특별시 중구 입정동 277      서울특별시 중구 을지로15길 31
# 8323  전환성공  6800.0    서울특별시 서초구 내곡동 384  서울특별시 서초구 내곡동 헌릉로8길 45
# 8324  전환성공  6798.0    서울특별시 서초구 신원동 557   서울특별시 서초구 헌릉로8길 10-12
#
#                          건물관리번호      동                     동도로명주소
# 0     1168010300106580001019759    개포동        서울특별시 강남구 개포동 언주로 3
# 1     1168010300106520000019285    개포동      서울특별시 강남구 개포동 개포로 307
# 2     1168010300100120002000001    개포동   서울특별시 강남구 개포동 개포로109길 69
# 3                           NaN    NaN                        NaN
# 4     1168010300101850000019804    개포동      서울특별시 강남구 개포동 개포로 516
# ...                         ...    ...                        ...
# 8320  1120011800100670005003280    송정동       서울특별시 성동구 송정동 송정길 32
# 8321  1114013400101510001014682  인현동2가     서울특별시 중구 인현동2가 마른내로 79
# 8322  1114015600101400004011835    입정동     서울특별시 중구 입정동 을지로15길 31
# 8323  1165010900101430000000001    내곡동         서울특별시 서초구 헌릉로8길 45
# 8324  1165011100104120005000002    신원동  서울특별시 서초구 신원동 헌릉로8길 10-12
#
# [8325 rows x 7 columns]

# %% [markdown]
# 건물관리번호(BD_MGT_SN)의 데이터 구성은 다음과 같습니다.
# 건물관리번호(25) : 시도(2)+시군구(3)+읍면동(3)+리(2)+산여부(1)+지번본번(4)+지번부번(4)+시스템번호(6)
#
# 건물관리번호는 건물 데이터를 식별하기 위한 PK이며,
# 최초 생성된 이후 해당 건물의 주소정보가 변경되어도 건물관리번호의 코드는 변경되지 않습니다.
# 따라서, 타 데이터와 매칭하기 위한 용도로 사용하시는 것은 적합하지 않습니다.
#
# 도로명주소DB와 타 데이터를 매칭하실 경우
# 도로명주소DB에서 제공되는 도로명주소 및 지번소재지 정보 컬럼을 조합하여 사용하실 것을 안내드립니다.
#
# [참조정보]
# 도로명주소 식별 컬럼조합 : 법정동코드(10자리 중 8자리)+도로명코드(12)+지하여부(1)+건물본번(5)+건물부번(5)
# 지번소재지 식별 컬럼조합 : 법정동코드(10)+산여부(1)+지번본번(4)+지번부번(4)
#
# *법정동코드(10) = 시도(2)+시군구(3)+읍면동(3)+리(2)
#
# 안내해 드린 내용이 도움이 되시기를 바라며.
# 기타 문의사항은 ☎ 1588-0061 로 문의하시기 바랍니다.
#
# https://business.juso.go.kr/addrlink/CommonPageLink.do?link=/addrlink/jusoHistory&cntcMenu=rdnm

# %%
doroaddress[doroaddress['도로명주소'].str.contains('헌릉로8길')==True].tail(1)
# Out:
#       결과코드    우편번호               지번주소                  도로명주소  \
# 8324  전환성공  6798.0  서울특별시 서초구 신원동 557  서울특별시 서초구 헌릉로8길 10-12
#
#                          건물관리번호    동                     동도로명주소
# 8324  1165011100104120005000002  신원동  서울특별시 서초구 신원동 헌릉로8길 10-12

# %%
doroaddress[doroaddress['도로명주소']=='서울특별시 서초구 헌릉로8길 45']
# Out:
# Empty DataFrame
# Columns: [결과코드, 우편번호, 지번주소, 도로명주소, 건물관리번호, 동, 동도로명주소]
# Index: []

# %% [markdown]
# ## 키 값은 '번지주소','층' ==> id로 만들어줌

# %%
len(train_test[train_test.is_test==1].id.unique()) # 7503

# %%
train_test['id'] = train_test['번지주소'] + ' ' + train_test['층'].astype(str) +'층'

# %%
filtered = train_test[train_test['is_test']==1][['번지주소','층']] # 9272 
len(filtered.duplicated()) # 9272
# Out:
# 9272

# %%
len(train_test[train_test['is_test']==1]['번지주소'].unique()) # 2588
# Out:
# 2588

# %%
len(train_test[train_test['is_test']==1]['번지주소'].unique()) # 2588
# Out:
# 2588

# %%
train_test[train_test['is_test']==1] # 9272

# %%
train_test.to_csv(r'C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\train_test.csv', index=False)

# %%
len(train_test[train_test.is_test==1].id.unique())
# Out:
# 7503

# %%
train_test['계약년월']
# Out:
# 0          201712
# 1          201712
# 2          201712
# 3          201801
# 4          201801
#             ...
# 1128089    202307
# 1128090    202307
# 1128091    202308
# 1128092    202309
# 1128093    202309
# Name: 계약년월, Length: 1128094, dtype: int64

# %%
# '계약년월'을 datetime 객체로 변환
train_test['계약년월_dt'] = pd.to_datetime(train_test['계약년월'], format='%Y%m')

# '계약년월_dt'에서 연도만 추출하여 '계약년' 컬럼 생성
train_test['계약년'] = train_test['계약년월_dt'].dt.year

# %%
train_test.drop(columns=['계약년월_dt'], inplace=True)

# %%
train_test.head(1)
# Out:
#              시군구     번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201712    8  3  1987
#
#    ...                  단지신청일    target is_test                 번지주소  \
# 0  ...  2022-11-17 10:19:06.0  124000.0       0  서울특별시 강남구 개포동 658-1
#
#                        id       계약년월일    구    동            도로명주소   계약년
# 0  서울특별시 강남구 개포동 658-1 3층  2017-12-08  강남구  개포동  서울특별시 강남구 언주로 3  2017
#
# [1 rows x 60 columns]

# %%
train_test['계약년월일'] = pd.to_datetime(train_test.계약년월.astype(str) + train_test.계약일.astype(str), format='%Y%m%d')

# %%
train_test['도로명주소'] = '서울특별시'+ ' '+ train_test.구 + ' ' +train_test.도로명

# %%
train_test.head(1)
# Out:
#              시군구     번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201712    8  3  1987
#
#      도로명  해제사유발생일 등기신청일자 거래유형 중개사소재지 k-단지분류(아파트,주상복합등등)     k-전화번호     k-팩스번호  \
# 0  언주로 3      NaN           -      -                아파트  025776611  025776673
#
#    단지소개기존clob k-세대타입(분양형태) k-관리방식 k-복도유형 k-난방방식  k-전체동수  k-전체세대수 k-건설사(시공사)  \
# 0         NaN           분양   자치관리    계단식   개별난방     8.0    270.0       우성건설
#
#   k-시행사          k-사용검사일-사용승인일    k-연면적  k-주거전용면적  k-관리비부과면적  \
# 0    모름  1987-11-21 00:00:00.0  22637.0   20204.0    22637.0
#
#    k-전용면적별세대현황(60㎡이하)  k-전용면적별세대현황(60㎡~85㎡이하)  k-85㎡~135㎡이하  k-135㎡초과 k-홈페이지  \
# 0                20.0                   250.0           0.0       NaN    NaN
#
#                   k-등록일자                 k-수정일자 고용보험관리번호 경비비관리형태 세대전기계약방법  \
# 0  2022-11-09 20:10:43.0  2023-09-23 17:21:41.0      NaN      직영     단일계약
#
#   청소비관리형태    건축면적   주차대수 기타/의무/임대/임의=1/2/3/4                  단지승인일 사용허가여부  \
# 0      직영  4858.0  262.0                  임의  2022-11-17 13:00:29.0      Y
#
#   관리비 업로드        좌표X        좌표Y                  단지신청일    target  is_test  \
# 0       N  127.05721  37.476763  2022-11-17 10:19:06.0  124000.0        0
#
#                   번지주소                      id      계약년월일    구    동  \
# 0  서울특별시 강남구 개포동 658-1  서울특별시 강남구 개포동 658-1 3층 2017-12-08  강남구  개포동
#
#              도로명주소
# 0  서울특별시 강남구 언주로 3

# %% [markdown]
# # 빈값 데이터 채우기
# https://data.seoul.go.kr/dataList/OA-15818/S/1/datasetView.do

# %%
df = pd.merge(train_test, seoul_apart, left_on='도로명주소', right_on='kapt도로명주소', how='left')

# %%
df.to_csv(r'C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\train_test_seoup_apart.csv')

# %%
df.head(2)
# Out:
#              시군구     번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  \
# 0  서울특별시 강남구 개포동  658-1 658.00 1.00  개포6차우성    79.97  201712    8  3  1987
# 1  서울특별시 강남구 개포동  658-1 658.00 1.00  개포6차우성    79.97  201712   22  4  1987
#
#    ... 청소비관리형태_y  건축면적_y 주차대수_y 기타/의무/임대/임의=1/2/3/4_y 단지승인일_y 사용허가여부_y  \
# 0  ...        직영 4858.00 262.00                    임의    0.00        Y
# 1  ...        직영 4858.00 262.00                    임의    0.00        Y
#
#   관리비 업로드_y      좌표X_y  좌표Y_y 단지신청일_y
# 0         N  127.05721  37.48    0.01
# 1         N  127.05721  37.48    0.01
#
# [2 rows x 107 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 히트맵 생성
plt.figure(figsize=(20, 6))  # 가로 16인치, 세로 6인치로 설정
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
train_test[train_test.is_test==0].target.isna().sum()
# Out:
# 0

# %%
train_test_seoul_apart.columns

# %%
train_test_seoul_apart.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적(㎡)', '계약년월', '계약일', '층', '건축년도',
#        '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)',
#        'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형',
#        'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일',
#        'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60㎡이하)',
#        'k-전용면적별세대현황(60㎡~85㎡이하)', 'k-85㎡~135㎡이하', 'k-135㎡초과', 'k-홈페이지',
#        'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태',
#        '건축면적', '주차대수', '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드',
#        '좌표X', '좌표Y', '단지신청일', 'target', 'is_test', '번지주소', 'id', '계약년월일', '구',
#        '동', '도로명주소', '계약년'],
#       dtype='object')

# %% [markdown]
# # 역 WGS1984
# https://business.juso.go.kr/addrlink/elctrnMapProvd/geoDBDwldList.do?menu=%EC%82%AC%EB%AC%BC%EC%A3%BC%EC%86%8C%20%EC%8B%9C%EC%84%A4%20%EA%B8%B0%EC%A4%80%EC%A0%90#this

# %%
train_test.좌표X.isna().sum()
# Out:
# 876232

# %%
train_test_seoul_apart.좌표X_y.isna().sum()
# Out:
# 273097

# %%
import numpy as np

subset = train_test_seoul_apart[['도로명주소','좌표X_y','좌표Y_y']].drop_duplicates() # 9334

# 버스 정류장 데이터
real_estate = pd.DataFrame({
    'Property_ID': subset.도로명주소,
    'X': subset.좌표X_y,
    'Y': subset.좌표Y_y,
})

Bus_stations = pd.DataFrame({
    'Bus_Station_ID': bus_feature['노드 ID'],
    'Station_Name': bus_feature.정류소명,
    'X': bus_feature.X좌표,
    'Y': bus_feature.Y좌표,
})

# 지하철 정류장 데이터
subway_stations = pd.DataFrame({
    'Subway_Station_ID': subway_feature.역사_ID,
    'Station_Name': subway_feature.역사명,
    'X': subway_feature.경도,
    'Y': subway_feature.위도,
})

def haversine_np(lon1, lat1, lon2, lat2):
    """Calculate the great circle distance between two points on the earth (specified in decimal degrees)"""
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c  # Multiply by Earth radius to get kilometers
    return km

# 가장 가까운 정류소 계산
def calculate_nearest_station(real_estate, stations):
    min_distances = []
    nearest_station_names = []
    for index, real in real_estate.iterrows():
        distances = haversine_np(real['X'], real['Y'], stations['X'].values, stations['Y'].values)
        min_index = distances.argmin()
        min_distances.append(distances[min_index])
        nearest_station_names.append(stations.iloc[min_index]['Station_Name'])
    return min_distances, nearest_station_names

# 버스 정류장
min_distances, nearest_station_names = calculate_nearest_station(real_estate, Bus_stations)
real_estate['Nearest_Bus_Station_Distance'] = min_distances
real_estate['Nearest_Bus_Station_Name'] = nearest_station_names

# 지하철역
min_distances, nearest_station_names = calculate_nearest_station(real_estate, subway_stations)
real_estate['Nearest_Subway_Station_Distance'] = min_distances
real_estate['Nearest_Subway_Station_Name'] = nearest_station_names

print(real_estate.head(1))

# %%
real_estate.head(5)
# Out:
#              Property_ID      X     Y  Nearest_Bus_Station_Distance  \
# 0        서울특별시 강남구 언주로 3 127.06 37.48                          0.06
# 12     서울특별시 강남구 개포로 307 127.06 37.48                          0.10
# 25  서울특별시 강남구 개포로109길 69 127.08 37.50                          0.20
# 38     서울특별시 강남구 개포로 310 127.06 37.48                          0.23
# 39     서울특별시 강남구 개포로 310 127.06 37.48                          0.23
#
#    Nearest_Bus_Station_Name  Nearest_Subway_Station_Distance  \
# 0                   개포우성아파트                             1.13
# 12                  우성3차아파트                             0.41
# 25                 코원에너지서비스                             0.40
# 38               개포주공1단지아파트                             0.76
# 39               개포주공1단지아파트                             0.73
#
#    Nearest_Subway_Station_Name
# 0                           구룡
# 12                          구룡
# 25                          대청
# 38                          구룡
# 39                          구룡

# %%
real_estate.to_csv(r'C:\Users\user\upstage3-python\12.upstage_project_House_Price_Prediction\asset\data\station_distance.csv', index=False)
